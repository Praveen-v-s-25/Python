# %% [markdown]
# Errors:
# 1. Compile time errors --- syntax errors
# 2. logical errors --- condition errrors wrong ouptut
# 3. runtime error --- compiled but the error occurs while user input (Divide by zero)
#
# ==> to handle the error we use the exception handling
# ==>
